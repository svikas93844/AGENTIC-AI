# %% [markdown]
# # 🏥 AGENTIC-AI MULTI AGENT HEALTH CARE MONITOR (Google Colab)
# Run the complete 20,000-sample ML model backend server and launch a public live web link directly inside Google Colab.

# %% [markdown]
# ### Step 1: Clone Repository & Install Dependencies

# %%
# !git clone https://github.com/svikas93844/AGENTIC-AI.git
# %cd AGENTIC-AI
# !pip install -r requirements.txt
# !pip install pyngrok

# %% [markdown]
# ### Step 2: Start Backend Server & Generate Live Public Web App Link

# %%
import subprocess
import time
from pyngrok import ngrok

# Start Python Backend Server in Background
server_process = subprocess.Popen(["python", "server.py"])
time.sleep(3)

# Create Public Live URL
public_url = ngrok.connect(8080)
print("\n=======================================================")
print(f"🚀 YOUR LIVE HEALTH CARE MONITOR IS READY AT:\n{public_url}")
print("=======================================================\n")
